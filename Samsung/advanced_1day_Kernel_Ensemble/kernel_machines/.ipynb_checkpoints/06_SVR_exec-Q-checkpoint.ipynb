# %% [markdown]
# # **실제 분류 데이터를 활용하여 SVR학습 모델 학습**

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler,normalize
from sklearn.metrics import confusion_matrix, mean_squared_error

import matplotlib.pyplot as plt
from sklearn.model_selection import StratifiedShuffleSplit, GridSearchCV, train_test_split

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# **mortgage - regression 예제**

# %% [markdown]
# 실제 분류 예제 데이터(mortgage.csv) 를 사용하여 인공신경망 모델을 학습해보겠습니다.
#
# 학습데이터를 정규화작업을 거쳐, 학습과 모델 평가를 위해 6:4의 비율로 학습데이터와 평가데이터로 나누어 보도록 보겠습니다.
#
# 또한, 예측 성능 평가를 위해 MAPE 성능지표 산출 함수를 정의하였습니다.

# %%
# read mortgage.csv
mor = "______________"
print(mor.shape)
# Out:
# (1049, 16)

# %%
mor
# Out:
#       OneMonthCDRate  OneY.CMaturityRate  ThreeM.Rate.AuctionAverage  \
# 0               8.72              90.729                        9.69
# 1              13.85             109.392                       17.19
# 2               6.59              87.979                        9.94
# 3              17.43              96.064                       15.07
# 4               3.16              85.121                        8.21
# 5               7.57              86.024                       10.61
# 6               6.30              87.478                        9.52
# 7               5.56             100.143                        6.92
# 8               7.81              94.470                       11.58
# 9              11.10              92.872                       13.43
# 10              9.06              88.515                       10.71
# 11             17.84             108.576                       17.48
# 12              3.10              86.414                        7.57
# 13              5.40              86.534                        8.92
# 14              5.93              77.839                        7.63
# 15              5.56              98.385                        6.91
# 16              4.43              84.839                        8.57
# 17              5.57              95.499                        7.22
# 18              3.88              85.363                        8.59
# 19              9.30             119.315                       13.65
# 20              9.25             128.936                       13.63
# 21              7.75             127.000                       12.11
# 22              7.86              81.967                       10.02
# 23              3.18              88.940                        7.17
# 24              9.36              94.842                       10.20
# 25              7.93              87.198                       10.64
# 26             13.54             117.652                       16.88
# 27             18.02             109.709                       17.26
# 28              5.49              85.834                        7.74
# 29              6.78             107.239                       10.61
# ...              ...                 ...                         ...
# 1019           15.02             106.149                       18.63
# 1020            4.04              81.975                        8.23
# 1021            6.55              87.470                        9.96
# 1022            5.56              96.498                        7.10
# 1023           15.43             107.001                       18.28
# 1024            5.52              83.141                        7.08
# 1025            4.50              84.900                        8.57
# 1026           13.34              94.960                       12.85
# 1027            4.80              83.476                        8.66
# 1028            8.43              91.769                        9.74
# 1029            6.65              82.872                        9.40
# 1030            8.01              91.584                       10.57
# 1031            5.23              86.130                        8.91
# 1032           15.44              94.976                       14.28
# 1033            5.54              91.688                        7.26
# 1034            5.88              88.252                        9.50
# 1035            3.34              87.343                        8.13
# 1036            9.01             118.322                       12.82
# 1037           17.87              95.040                       14.95
# 1038            5.27              85.299                        7.88
# 1039            5.44              93.179                        6.69
# 1040            8.08              81.963                       10.24
# 1041            5.31              89.924                        7.65
# 1042            6.01              83.856                        8.84
# 1043            5.30              84.112                        7.53
# 1044            9.34              85.261                       10.46
# 1045            7.28              83.494                        9.63
# 1046            5.72              92.767                        8.18
# 1047            8.19              91.191                       10.12
# 1048           10.21             132.995                       14.10
#
#       ThreeM.Rate.SecondaryMarket  ThreeY.CMaturityRate  FiveY.CMaturityRate  \
# 0                            7.62                  7.60                 7.72
# 1                           12.06                 12.47                13.94
# 2                            5.74                  5.67                 7.42
# 16               1145.9        794.6           2252.4           1208.0
# 17               1078.6        635.3           3107.8           1470.4
# 18                952.6        668.7           2106.4           1130.8
# 19                511.5        364.8           1119.2            689.7
# 20                549.4        389.2           1320.9            693.4
# 21                600.1        428.8           1423.4            788.7
# 22                823.7        570.6           2110.9            922.9
# 23               1131.5        801.4           2194.2           1218.9
# 24                773.0        548.7           1944.2            858.2
# 25                749.5        546.4           1717.7            935.9
# 26                448.9        315.6           1064.0            341.8
# 27                426.8        301.8            970.5            352.9
# 28               1082.2        679.5           2784.3           1273.0
# 29                662.6        481.9           1527.6            872.4
# ...                 ...          ...              ...              ...
# 1019              428.4        303.7            985.9            343.6
# 1020              906.5        630.6           2116.4           1060.2
# 1021              760.4        554.1           1751.1            943.3
# 1022             1073.8        629.2           3110.1           1482.0
# 1023              427.3        302.9            988.3            346.0
# 1024             1129.4        746.9           2650.5           1149.5
# 1025             1151.5        796.8           2291.7           1197.4
# 1026              383.1        274.4            868.1            193.0
# 1027             1153.2        796.5           2305.6           1189.9
# 1028              789.2        561.6           2017.1            890.7
# 1029              835.2        572.6           2126.1            940.4
# 1030              785.2        569.4           1829.4            954.5
# 1031              881.7        609.5           2107.3           1024.0
# 1032              410.4        292.2            914.4            412.2
# 1033             1063.8        637.3           2984.3           1377.7
# 1034              850.8        586.3           2118.4            971.8
# 1035             1026.9        726.0           2110.2           1185.6
# 1036              504.4        360.3           1103.2            687.0
# 1037              406.9        288.1            929.1            387.2
# 1038             1082.6        683.6           2747.1           1250.4
# 1039             1093.0        626.0           3334.0           1600.8
# 1040              816.8        564.7           2105.6            922.5
# 1041             1075.2        668.7           2815.6           1290.2
# 1042             1144.8        778.7           2425.7           1115.8
# 1043             1077.3        677.2           2757.6           1262.9
# 1044              787.1        569.3           1866.6            928.4
# 1045              825.4        568.2           2112.1            926.2
# 1046             1120.6        587.7           3532.6           1737.8
# 1047              809.2        567.6           2066.7            914.8
# 1048              542.0        382.6           1302.8            687.2
#
#       ThirtyY.CMortgageRate
# 0                      7.66
# 1                     13.73
# 2                      6.65
# 3                     14.24
# 4                      3.50
# 5                      7.15
# 6                      6.34
# 7                      5.24
# 8                      8.33
# 9                     12.07
# 10                     8.96
# 11                    17.07
# 12                     3.31
# 13                     5.50
# 14                     5.53
# 15                     5.34
# 16                     5.47
# 17                     5.45
# 18                     4.27
# 19                    10.31
# 20                     9.99
# 21                     7.97
# 22                     7.30
# 23                     3.60
# 24                     8.40
# 25                     7.19
# 26                    13.46
# 27                    16.74
# 28                     5.51
# 29                     6.61
# ...                     ...
# 1019                  15.53
# 1020                   4.06
# 1021                   6.72
# 1022                   5.45
# 1023                  16.52
# 1024                   5.17
# 1025                   5.60
# 1026                  12.02
# 1027                   5.72
# 1028                   7.73
# 1029                   6.40
# 1030                   8.17
# 1031                   5.39
# 1032                  14.20
# 1033                   5.45
# 1034                   6.13
# 1035                   3.64
# 1036                   9.64
# 1037                  13.86
# 1038                   5.55
# 1039                   4.49
# 1040                   7.58
# 1041                   5.49
# 1042                   6.70
# 1043                   5.42
# 1044                   8.89
# 1045                   6.71
# 1046                   6.12
# 1047                   8.05
# 1048                  10.93
#
# [1049 rows x 16 columns]

# %%
mor_y = "____________"
mor_x = "____________"
print('X:',mor_x.shape)
print('y:',mor_y.shape)
# Out:
# X: (1049, 15)
# y: (1049,)

# %% [markdown]
# - 데이터 정규화

# %%
scaler = "____________"
scaler
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
transformer = scaler."____________"
transformer
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
mor_x = transformer."____________"
mor_x
# Out:
# array([[ 0.35491563, -0.45799122, -0.2403576 , ...,  0.09625994,
#          0.0848087 , -0.16115823],
#        [ 1.8746428 ,  0.83226746,  2.29560079, ..., -1.49612074,
#         -1.28483455, -1.64134569],
#        [-0.2760822 , -0.64811132, -0.15582566, ...,  0.00836053,
#         -0.29884137, -0.04882737],
#        ...,
#        [-0.53381371, -0.31709495, -0.75093056, ...,  0.24212201,
#          2.18481727,  2.10453902],
#        [ 0.19790678, -0.42605105, -0.09496266, ...,  0.11409461,
#          0.14937522, -0.10714267],
#        [ 0.79631787,  2.46405097,  1.25078593, ..., -1.0642671 ,
#         -0.91132073, -0.7187815 ]])

# %%
mor_train_x, mor_test_x, mor_train_y, mor_test_y = train_test_split(mor_x, mor_y, test_size=0.4, random_state=0)

# %% [markdown]
# ---

# %% [markdown]
# - 실제값 대비 잔차가 얼마나 좋아졌는지 확인

# %% [markdown]
# $$MAPE = \frac{100\%}{n} \sum^{n}_{t=1}|\frac{A_t-F_t}{A_t}|$$

# %% [markdown]
# $A_t$: actual value

# %% [markdown]
# $F_t$: forecast value

# %%
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %% [markdown]
# ---

# %% [markdown]
# ### 단순 Multiple Linear Regression 학습 모델과의 비교
#
# SVM regression과 단순한 MLR(Multiple Linear Regression)의 성능 비교를 위해 MLR학습 모델을 정의하였습니다.

# %%
#  package
from sklearn.linear_model import LinearRegression

# model/fit
mor_regression = LinearRegression()
mor_regression."____________"

# prediction
mor_regression_pred = mor_regression."____________"

# eval
mor_regression_mape = mean_absolute_percentage_error(mor_test_y,mor_regression_pred)
mor_regression_rmse = np.sqrt(mean_squared_error(y_true=mor_test_y, y_pred=mor_regression_pred))

print('==== mortgage - regression ================')
print('MAPE:{}'.format(mor_regression_mape))
print('===========================================')
# Out:
# ==== mortgage - regression ================
# MAPE:1.153271361250734
# ===========================================

# %% [markdown]
# ---

# %% [markdown]
# ### Neural Network Regression 학습 모델과의 비교
#
# SVM regression과 ANN regression의 성능 비교를 위해 모델을 정의하였습니다.
#
# 기본적인 학습 파라미터인 'hidden node'와 'max_iteration'을 cross-valdation을 통해서 최적화를 진행하였습니다.

# %%
### Neural Network model training
from sklearn.neural_network import MLPRegressor
def NN_CV_regresser(train_x, train_y, max_nodes,CV_N ,plot=False):
    
    #1부터 10까지의 neighbor에 대해 최적의 k를 cross-validation을 이용하여 찾아냄
    parameters = {'hidden_layer_sizes': np.arange(start=1, stop=max_nodes,step=10).tolist(),
                  'max_iter': [50,100,200,300,400,500]}
    
    # MLPRegressor(learning_rate_init=0.01)
    clf = "____________"
    
    grid_clf = "____________"
    
    # fitting
    grid_clf."____________"

    print( grid_clf.best_params_)
    
    optimal_parameters = list(grid_clf.best_params_.values())

    print("The optimal number of hidden nodes : {}\n& max iteration : {}".format(optimal_parameters[0],optimal_parameters[1]))

    opt_NN = MLPRegressor(hidden_layer_sizes=grid_clf.best_params_['hidden_layer_sizes'],
                          max_iter=grid_clf.best_params_['max_iter'])
    opt_NN.fit(X=train_x, y=train_y)

    return opt_NN

# %%
mor_optNNR=NN_CV_regresser(train_x=mor_train_x, train_y=mor_train_y,max_nodes=100,CV_N=5)
mor_optNNR_pred = mor_optNNR."____________"
# Out:
# {'hidden_layer_sizes': 91, 'max_iter': 500}
# The optimal number of hidden nodes : 91
#   & max iteration : 500

# %%
mor_nnr_mape = mean_absolute_percentage_error(mor_test_y,mor_optNNR_pred)
mor_nnr_rmse = np.sqrt(mean_squared_error(y_true=mor_test_y, y_pred=mor_optNNR_pred))

print('==== mortgage - NN regression ================')
print('MAPE:{}'.format(mor_nnr_mape))
print('==============================================')
# Out:
# ==== mortgage - NN regression ================
# MAPE:2.6285673841415296
# ==============================================

# %% [markdown]
# ---

# %% [markdown]
# ### Kernel SVR

# %%
def CV_SVR_classifier(train_x, train_y,CV_n):
    parameters =  {'C':[0.01,0.05,0.1,1,5,10,],'gamma':[0.01,0.02,0.06,0.08,0.1,1,2,10], 'epsilon':[0.01,0.1,1]}
    print("매개변수 그리드:\n{}".format(parameters))
 
    # RBF SVR instance 생성
    clf = "____________"

    # Grid RBF SVR instance 생성
    grid_clf = "____________"
    
    # fitting with cross-validation
    grid_clf."____________"

    print(grid_clf.best_params_)
    

    print("The optimal 'C' : {}\nThe optimal 'epsilon' : {}\nThe optimal 'Gamma' : {}".format(grid_clf.best_params_['C'],
                                                                                              grid_clf.best_params_['epsilon'],
                                                                                              grid_clf.best_params_['gamma']))
    # using best params
    opt_SVR = "____________"
    
    # fitting
    opt_SVR."____________"
    
    return opt_SVR

# %%
mor_opt_SVR = CV_SVR_classifier(train_x=mor_train_x, train_y=mor_train_y,CV_n=10)
mor_opt_SVR
# Out:
# 매개변수 그리드:
# {'C': [0.01, 0.05, 0.1, 1, 5, 10], 'gamma': [0.01, 0.02, 0.06, 0.08, 0.1, 1, 2, 10], 'epsilon': [0.01, 0.1, 1]}
# {'C': 10, 'epsilon': 0.01, 'gamma': 0.1}
# The optimal 'C' : 10
# The optimal 'epsilon' : 0.01
# The optimal 'Gamma' : 0.1
# SVR(C=10, cache_size=200, coef0=0.0, degree=3, epsilon=0.01, gamma=0.1,
#   kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %%
mor_opt_SVR_pred = mor_opt_SVR."____________"

# %%
mor_svr_mape = mean_absolute_percentage_error(mor_test_y,mor_opt_SVR_pred)
mor_svr_rmse = np.sqrt(mean_squared_error(y_true=mor_test_y, y_pred=mor_opt_SVR_pred))

print('==== mortgage - SVM regression ================')
print('MAPE:{}'.format(round(mor_svr_mape,4)))
print('===============================================')
# Out:
# ==== mortgage - SVM regression ================
# MAPE:0.6545
# ===============================================

# %% [markdown]
# ---

# %% [markdown]
# - **세가지 모델('MLR', 'ANN', 'SVR')의 예측 성능 비교**

# %%
# pd.DataFrame([], index =[], columns=[])
"____________"
# Out:
#            RMSE      MAPE
# L_reg  0.114446  1.153271
# NN     0.239643  2.628567
# SVR    0.073614  0.654490
