# %% [markdown]
# # **Support Vector Regression**

# %%
# %matplotlib inline
import numpy as np
from sklearn.svm import SVR
import matplotlib.pyplot as plt
from sklearn.model_selection import StratifiedShuffleSplit, GridSearchCV, train_test_split

# %%
# np.random.rand(n,m): nxm matrix (0~1)
np.random.rand(40, 1)
# Out:
# array([[0.0066434 ],
#        [0.72052208],
#        [0.99017209],
#        [0.62094784],
#        [0.70576918],
#        [0.08802297],
#        [0.00151138],
#        [0.98501494],
#        [0.28506037],
#        [0.26581014],
#        [0.66490971],
#        [0.92222409],
#        [0.69371942],
#        [0.85380174],
#        [0.62287844],
#        [0.92911515],
#        [0.32479606],
#        [0.87775274],
#        [0.9057864 ],
#        [0.01278993],
#        [0.50347231],
#        [0.69107761],
#        [0.73643557],
#        [0.55637169],
#        [0.67836872],
#        [0.07204829],
#        [0.99430341],
#        [0.31297993],
#        [0.94799543],
#        [0.21505973],
#        [0.866427  ],
#        [0.17062716],
#        [0.92932143],
#        [0.70145313],
#        [0.35503825],
#        [0.30026177],
#        [0.89699048],
#        [0.35836165],
#        [0.49235001],
#        [0.74938503]])

# %%
# Generate sample data
X = np.sort(5 * np.random.rand(40, 1), axis=0)
X
# Out:
# array([[0.07482558],
#        [0.3490774 ],
#        [0.68496781],
#        [0.84194832],
#        [0.90703036],
#        [1.11865985],
#        [1.17660244],
#        [1.21973872],
#        [1.46433167],
#        [1.51306433],
#        [1.94436134],
#        [1.97678739],
#        [2.0627195 ],
#        [2.07022469],
#        [2.19545057],
#        [2.22923669],
#        [2.2790252 ],
#        [2.29170182],
#        [2.37782836],
#        [2.47488669],
#        [2.7263844 ],
#        [2.89327226],
#        [2.9106772 ],
#        [2.97916639],
#        [3.13643271],
#        [3.15354373],
#        [3.18272283],
#        [3.30470873],
#        [3.51532018],
#        [3.54416431],
#        [3.55334469],
#        [3.69475989],
#        [3.95678687],
#        [4.03886186],
#        [4.11367186],
#        [4.13310466],
#        [4.15704309],
#        [4.28852788],
#        [4.33338524],
#        [4.60884054]])

# %%
y = np.sin(X).ravel()
y
# Out:
# array([ 0.07475577,  0.342031  ,  0.63264808,  0.74594213,  0.78767766,
#         0.89951576,  0.92330646,  0.93900954,  0.99433799,  0.99833397,
#         0.93103226,  0.91871145,  0.88142613,  0.87785648,  0.81116537,
#         0.79094751,  0.75951516,  0.75120835,  0.69164505,  0.61840069,
#         0.40338049,  0.24577622,  0.22886877,  0.161713  ,  0.00515992,
#        -0.01195079, -0.04111858, -0.16239371, -0.36508819, -0.3917857 ,
#        -0.40021555, -0.52538475, -0.72785879, -0.7816265 , -0.82605931,
#        -0.83685465, -0.84971813, -0.91150773, -0.92903371, -0.99464365])

# %%
y[::5]
# Out:
# array([ 0.07475577,  0.89951576,  0.93103226,  0.79094751,  0.40338049,
#        -0.01195079, -0.40021555, -0.83685465])

# %%
# Add noise to targets
y[::5] += 3 * (0.5 - np.random.rand(8))
y
# Out:
# array([-0.83734645,  0.342031  ,  0.63264808,  0.74594213,  0.78767766,
#         0.15826741,  0.92330646,  0.93900954,  0.99433799,  0.99833397,
#        -0.31192311,  0.91871145,  0.88142613,  0.87785648,  0.81116537,
#         0.96044018,  0.75951516,  0.75120835,  0.69164505,  0.61840069,
#        -0.43873394,  0.24577622,  0.22886877,  0.161713  ,  0.00515992,
#         0.54763945, -0.04111858, -0.16239371, -0.36508819, -0.3917857 ,
#        -0.47117044, -0.52538475, -0.72785879, -0.7816265 , -0.82605931,
#        -0.83549768, -0.84971813, -0.91150773, -0.92903371, -0.99464365])

# %%
# Fit regression model
svr_lin = SVR(kernel='linear', C=1e3)
svr_poly = SVR(kernel='poly', C=1e3, degree=2)
svr_rbf = SVR(kernel='rbf', C=1e3, gamma=0.1)

y_lin = svr_lin.fit(X, y).predict(X)
y_poly = svr_poly.fit(X, y).predict(X)
y_rbf = svr_rbf.fit(X, y).predict(X)

# %%
# Look at the results
plt.figure(figsize=(9,7))
lw = 2
plt.scatter(X, y, color='darkorange', label='data')
plt.plot(X, y_rbf, color='navy', lw=lw, label='RBF model')
plt.plot(X, y_lin, color='c', lw=lw, label='Linear model')
plt.plot(X, y_poly, color='cornflowerblue', lw=lw, label='Polynomial model')
plt.xlabel('data')
plt.ylabel('target')
plt.title('Support Vector Regression')
plt.legend()

# %% [markdown]
# - **Sinusoid dataset**
#     - 좀 더 복잡한 데이터에 대해서 fitting에 보도록 하겠습니다.

# %%
plt.figure(figsize=(9,7))
N = 200 # number of data points
x = np.linspace(0, 4*np.pi, N)
y = 3.0*np.sin(x+0.001) + 0.5 + np.random.randn(N) # create artificial data with noise
plt.scatter(x, y)

# %%
x[0:5]
# Out:
# array([0.        , 0.06314759, 0.12629518, 0.18944277, 0.25259036])

# %% [markdown]
# - input shape (1,) -> (1,1)

# %%
x="___________"
x[0:5]
# Out:
# array([[0.        ],
#        [0.06314759],
#        [0.12629518],
#        [0.18944277],
#        [0.25259036]])

# %%
# Fit regression model
svr_lin = SVR(kernel='linear', C=1e3)
svr_poly = SVR(kernel='poly', C=1e3, degree=2, epsilon = 0.1)
svr_rbf = SVR(kernel='rbf', C=1e3, gamma=0.1, epsilon = 0.1)

y_lin = svr_lin.fit(x, y).predict(x)
y_poly = svr_poly.fit(x, y).predict(x)
y_rbf = svr_rbf.fit(x, y).predict(x)

# %%
# Look at the results
plt.figure(figsize=(9,7))

lw = 2
plt.scatter(x, y, color='darkorange')
plt.plot(x, y_rbf, color='navy', lw=lw)
plt.plot(x, y_lin, color='c', lw=lw)
plt.plot(x, y_poly, color='cornflowerblue', lw=lw)

# %% [markdown]
# # **SVR hyperparameters**

# %% [markdown]
# <p align="center"><img width="600" height="auto" src="./images/svr.png"></p>

# %% [markdown]
# **param1: $\varepsilon$**

# %% [markdown]
# $(-\varepsilon, + \varepsilon)$ 사이에 있는 error는 0으로 취급

# %% [markdown]
# **param2:** $C \rightarrow$ margin $\xi$

# %% [markdown]
# margin $\xi$에 penalty $C$가 곱해져 목적함수에 더 해짐

# %% [markdown]
# $$ \frac{1}{2} ||w||^{2} + C \sum_{i=1}^{l}(\xi_i + \xi_i^{*})$$

# %% [markdown]
# **param3: $\gamma$**$\rightarrow$ kernel function RBF

# %% [markdown]
# $$ k(x,x^{'}) = \frac{\exp(-{||x-x^{'}||}^2)}{\sigma} = \exp(-\gamma{||x-x^{'}||}^2)$$

# %% [markdown]
# - grid search

# %%
parameters = {'kernel':['rbf'] ,
              'C':np.logspace(-3,5,5),
              'gamma': np.logspace(-3,5,5),
              'epsilon':np.logspace(-3,5,10)}
parameters
# Out:
# {'kernel': ['rbf'],
#  'C': array([1.e-03, 1.e-01, 1.e+01, 1.e+03, 1.e+05]),
#  'gamma': array([1.e-03, 1.e-01, 1.e+01, 1.e+03, 1.e+05]),
#  'epsilon': array([1.00000000e-03, 7.74263683e-03, 5.99484250e-02, 4.64158883e-01,
#         3.59381366e+00, 2.78255940e+01, 2.15443469e+02, 1.66810054e+03,
#         1.29154967e+04, 1.00000000e+05])}

# %%
svr = "____________"
clf = "____________"

# %%
clf.fit(x,y)
# Out:
# GridSearchCV(cv=None, error_score='raise',
#        estimator=SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'kernel': ['rbf'], 'C': array([1.e-03, 1.e-01, 1.e+01, 1.e+03, 1.e+05]), 'gamma': array([1.e-03, 1.e-01, 1.e+01, 1.e+03, 1.e+05]), 'epsilon': array([1.00000e-03, 7.74264e-03, 5.99484e-02, 4.64159e-01, 3.59381e+00,
#        2.78256e+01, 2.15443e+02, 1.66810e+03, 1.29155e+04, 1.00000e+05])},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=0)

# %%
clf.best_params_
# Out:
# {'C': 10.0, 'epsilon': 0.007742636826811269, 'gamma': 0.1, 'kernel': 'rbf'}

# %% [markdown]
# - best model

# %%
svr = SVR(kernel='rbf', 
          C=clf.best_params_['C'],
          epsilon=clf.best_params_['epsilon'], 
          gamma = clf.best_params_['gamma'])
svr.fit(x,y)
# Out:
# SVR(C=10.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.007742636826811269,
#   gamma=0.1, kernel='rbf', max_iter=-1, shrinking=True, tol=0.001,
#   verbose=False)

# %%
pred_y = svr."____________"

# %%
# Look at the results
plt.figure(figsize=(9,7))

lw = 2
plt.scatter(x, y, color='darkorange', label='data')
plt.plot(x, pred_y, color='navy', lw=lw, label='RBF model')

plt.xlabel('data')
plt.ylabel('target')
plt.title('Support Vector Regression')
plt.legend()

# %% [markdown]
# ---
